# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
house_data=pd.read_csv('kc_house_data.csv')

house_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
house_data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
house_data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
house_data.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
house_data.isnull().any()
# Out:
# id               False
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
sns.distplot(house_data['sqft_lot'])
# Out:
# C:\Users\shurastogi\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(house_data['grade'])
# Out:
# C:\Users\shurastogi\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(house_data['bathrooms'])
# Out:
# C:\Users\shurastogi\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(house_data['bedrooms'])
# Out:
# C:\Users\shurastogi\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(house_data['price'])
# Out:
# C:\Users\shurastogi\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(house_data['sqft_living'])
# Out:
# C:\Users\shurastogi\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#UNIVARIATE ANALYSIS
#skewness above +1 or below -1
from scipy.stats import skew
skew(house_data['price'])
# Out:
# 4.023789858140135

# %%
#price is right skewed(positive)
house_data['price_norm'] = (house_data['price']-house_data['price'].mean())/house_data['price'].std()

# %%
#taking the norm also didnt not remove skewness 
sns.distplot(house_data['price_norm'])
# Out:
# C:\Users\shurastogi\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#to remove postive skewneww we can use cubesqrt/sqrt/log
#of all the case in this scenario log give best in skewness so will use price_log 
from scipy.stats import skew
skew(house_data['price'])
house_data['price_cubesqrt']=house_data['price']**(1/2)
house_data['price_log']=np.log(house_data['price'])

# %%
skew(house_data['price_cubesqrt'])
# Out:
# 1.656276840553054

# %%
skew(house_data['price_log'])
# Out:
# 0.42804276562854765

# %%
#use age as years renovated and years built is  of no use
#use current year
house_data["house_age"] = 2018- np.where(house_data["yr_renovated"]==0,house_data["yr_built"],house_data["yr_renovated"])

# %%
#calclating sqlft living and lot if they are changes for renovation
house_data["sqft_living"] = np.where(house_data["yr_renovated"]==0,house_data["sqft_living"],house_data["sqft_living15"])
house_data["sqft_lot"] = np.where(house_data["yr_renovated"]==0,house_data["sqft_lot"],house_data["sqft_lot15"])
print(skew(house_data["sqft_lot"]))
house_data['sqft_lot']=np.log(house_data['sqft_lot'])
print(skew(house_data["sqft_lot"]))
# Out:
# 13.26148264252223
# 0.9571348292332555

# %%
house_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         1690
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view    ...      yr_renovated  zipcode  \
# 0  8.639411     1.0           0     0    ...                 0    98178
# 1  8.941022     2.0           0     0    ...              1991    98125
# 2  9.210340     1.0           0     0    ...                 0    98028
# 3  8.517193     1.0           0     0    ...                 0    98136
# 4  8.997147     1.0           0     0    ...                 0    98074
#
#        lat     long  sqft_living15  sqft_lot15  price_norm  price_cubesqrt  \
# ...

# %%
house_data['ppsq']=house_data['price']/house_data['sqft_living']

# %%
f, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(house_data.corr(),annot=True)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
from scipy import stats
 
F, p = stats.f_oneway(house_data['price'], house_data['bedrooms'], house_data['sqft_living'])

# %%
F,p
# Out:
# (46595.95826356074, 0.0)

# %%
#reasoning with not selecting datapreprocessing.zip
#ID doesnt provide any info,so is date
#sqft living is sum sqft above and basement so will not include basement and above in model
#lat and long doesnt provide any significant help in this case
#Sqft_lot ,'sqft_living15', 'sqft_lot15' have no significance in model so dropping
#condition is inversely corelated with yr_ so removing condition
house_data.drop(['id'], axis=1, inplace=True)
house_data.drop(['date'], axis=1, inplace=True)
house_data.drop(['lat'], axis=1, inplace=True)
house_data.drop(['long'], axis=1, inplace=True)
house_data.drop(['sqft_above'], axis=1, inplace=True)
house_data.drop(['sqft_basement'], axis=1, inplace=True)
house_data.drop(['condition'], axis=1, inplace=True)
house_data.drop(['yr_renovated'], axis=1, inplace=True)
house_data.drop(['yr_built'], axis=1, inplace=True)
house_data.drop(['price_cubesqrt'], axis=1, inplace=True)
#house_data.drop(['price'], axis=1, inplace=True)
house_data.drop(['sqft_lot15'], axis=1, inplace=True)
house_data.drop(['sqft_living15'], axis=1, inplace=True)
house_data.drop(['price_norm'], axis=1, inplace=True)

# %%
house_data.drop(house_data[house_data.bedrooms==33].index,inplace=True)

# %%
columns=house_data.columns
for col in columns :
    print(col)
    print("Skew: {}".format(skew(house_data[col])))
#Price we already handled
# Out:
# price
# Skew: 4.023754298653168
# bedrooms
# Skew: 0.518432587839785
# bathrooms
# Skew: 0.5110074063486063
# sqft_living
# Skew: 1.4046010826014197
# sqft_lot
# Skew: 0.957076476693902
# floors
# Skew: 0.6160639626995856
# waterfront
# Skew: 11.384048334274553
# view
# Skew: 3.3954162735553526
# grade
# Skew: 0.7709790610378265
# zipcode
# Skew: 0.40569010733802663
# price_log
# Skew: 0.4281181214845604
# house_age
# Skew: 0.5565546572054456
# ppsq
# Skew: 1.6033711482822293

# %%
house_data['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10], dtype=int64)

# %%
df_bed=pd.get_dummies(house_data['bedrooms'],prefix='bedrooms_',drop_first=True)

# %%
house_data.drop(['bedrooms'],axis=1,inplace=True)

# %%
house_data=pd.concat([house_data,df_bed],axis=1)

# %%
dd=pd.qcut(house_data.sqft_living,q=[0, .25, .5, .75, 1.])

# %%
pd.Categorical(dd)
# Out:
# [(289.999, 1420.0], (1420.0, 1900.0], (289.999, 1420.0], (1900.0, 2520.0], (1420.0, 1900.0], ..., (1420.0, 1900.0], (1900.0, 2520.0], (289.999, 1420.0], (1420.0, 1900.0], (289.999, 1420.0]]
# Length: 21612
# Categories (4, interval[float64]): [(289.999, 1420.0] < (1420.0, 1900.0] < (1900.0, 2520.0] < (2520.0, 13540.0]]

# %%
dd
# Out:
# 0        (289.999, 1420.0]
# 1         (1420.0, 1900.0]
# 2        (289.999, 1420.0]
# 3         (1900.0, 2520.0]
# 4         (1420.0, 1900.0]
# 5        (2520.0, 13540.0]
# 6         (1420.0, 1900.0]
# 7        (289.999, 1420.0]
# 8         (1420.0, 1900.0]
# 9         (1420.0, 1900.0]
# 10       (2520.0, 13540.0]
# 11       (289.999, 1420.0]
# 12        (1420.0, 1900.0]
# 13       (289.999, 1420.0]
# 14        (1420.0, 1900.0]
# 15       (2520.0, 13540.0]
# 16        (1420.0, 1900.0]
# 17        (1420.0, 1900.0]
# 18       (289.999, 1420.0]
# 19       (289.999, 1420.0]
# 20        (1420.0, 1900.0]
# 21       (2520.0, 13540.0]
# 22        (1900.0, 2520.0]
# 23       (289.999, 1420.0]
# 24        (1900.0, 2520.0]
# 25        (1420.0, 1900.0]
# 26        (1900.0, 2520.0]
# 27       (289.999, 1420.0]
# 28        (1420.0, 1900.0]
# 29       (2520.0, 13540.0]
#                ...
# 21583    (289.999, 1420.0]
# 21584    (289.999, 1420.0]
# 21585     (1420.0, 1900.0]
# ...

# %%
dd=pd.get_dummies(dd,prefix='sqft_living')

# %%
dd
# Out:
#        sqft_living_(289.999, 1420.0]  sqft_living_(1420.0, 1900.0]  \
# 0                                  1                             0
# 1                                  0                             1
# 2                                  1                             0
# 3                                  0                             0
# 4                                  0                             1
# 5                                  0                             0
# 6                                  0                             1
# 7                                  1                             0
# 8                                  0                             1
# 9                                  0                             1
# 10                                 0                             0
# 11                                 1                             0
# 12                                 0                             1
# ...

# %%
#dd=dd.rename(index=str, columns={"sqft_living_(289.999, 1426.5]":"Very_Small_Apt","sqft_living_(1426.5, 1910.0]": "Small_Apt", "sqft_living_(1910.0, 2550.0]": "Medium_Apt","sqft_living_(2550.0, 13540.0]":"Large_apt"})
dd=dd.rename(index=str, columns={"sqft_living_(289.999, 1420.0]":"Very_Small_Apt","sqft_living_(1420.0, 1900.0]": "Small_Apt", "sqft_living_(1900.0, 2520.0]": "Medium_Apt","sqft_living_(2520.0, 13540.0]":"Large_apt"})

# %%
dd
# Out:
#        Very_Small_Apt  Small_Apt  Medium_Apt  Large_apt
# 0                   1          0           0          0
# 1                   0          1           0          0
# 2                   1          0           0          0
# 3                   0          0           1          0
# 4                   0          1           0          0
# 5                   0          0           0          1
# 6                   0          1           0          0
# 7                   1          0           0          0
# 8                   0          1           0          0
# 9                   0          1           0          0
# 10                  0          0           0          1
# 11                  1          0           0          0
# 12                  0          1           0          0
# 13                  1          0           0          0
# 14                  0          1           0          0
# 15                  0          0           0          1
# ...

# %%
house_data.drop(['sqft_living'],axis=1,inplace=True)

# %%
house_data.index=dd.index
house_data['Very_Small_Apt']=dd['Very_Small_Apt']
house_data['Small_Apt']=dd['Small_Apt']
house_data['Medium_Apt']=dd['Medium_Apt']
house_data['Large_apt']=dd['Large_apt']

# %%
house_data['zipcode'].unique()
# Out:
# array([98178, 98125, 98028, 98136, 98074, 98053, 98003, 98198, 98146,
#        98038, 98007, 98115, 98107, 98126, 98019, 98103, 98002, 98133,
#        98040, 98092, 98030, 98119, 98112, 98052, 98027, 98117, 98058,
#        98001, 98056, 98166, 98023, 98070, 98148, 98105, 98042, 98008,
#        98059, 98122, 98144, 98004, 98005, 98034, 98075, 98116, 98010,
#        98118, 98199, 98032, 98045, 98102, 98077, 98108, 98168, 98177,
#        98065, 98029, 98006, 98109, 98022, 98033, 98155, 98024, 98011,
#        98031, 98106, 98072, 98188, 98014, 98055, 98039], dtype=int64)

# %%
zip_dum=pd.get_dummies(house_data['zipcode'],prefix="zip_")

# %%
house_data=pd.concat([house_data,zip_dum],axis=1)

# %%
###house_data['zipcode']=house_data['zipcode'].replace({98039:"Medina",98014:"Carnation",98188:"Seatac",98031:"East Hill Meridian",98011:"Bothell",
                           ###98024:"Fall city",98072:"Woodinville",98022:"Enumclaw",98065:"Snoqualmie",98177:"Shoreline",98155:"Shoreline",
                           ###98168:"Tukwila",98077:"Cottage lake",98045:"North Bend",98010:"Black Diamond",98034:"Kirkland",
                           ###98166:"Burien",98148:"Burien",98070:"Vashon",98042:"covington",98033:"Kirkland",
                           ###98055:"Renton",98056:"Renton",98059:"Renton",98001:"Lakeland North",98058:"Fairwood",
                           ###98029:"Issaquah",98027:"Issaquah",98052:"Redmond",98030:"Kent",98032:"kent",
                           ###98040:"Mercer Island",98002:"Auburn",98092:"Auburn",98019:"Duvall",
                           ###98004:"Bellevue",98005:"Bellevue",98006:"Bellevue",98007:"Bellevue",98008:"Bellevue",
                           ###98038:"Maple Valley",98146:"White center",98198:"Des moines",98003:"Federal way",98023:"Federal way",
                           ###98053:"Union Hill-Novelty Hill",98074:"Sammamish",98075:"Sammamish",98028:"Kenmore",98178:"Bryn Mawr-Skyway",
                           ###98125:"Seattle",98136:"Seattle",98115:"Seattle",98107:"Seattle",98126:"Seattle",
                           ###98103:"Seattle",98133:"Seattle",98119:"Seattle",98112:"Seattle",98117:"Seattle",
                           ###98105:"Seattle",98122:"Seattle",98144:"Seattle",98116:"Seattle",98118:"Seattle",
                           ###98199:"Seattle",98102:"Seattle",98108:"Seattle",98109:"Seattle",98106:"Seattle"})

# %%
house_data.drop(['zipcode'],inplace=True,axis=1)

# %%
df_grade=pd.get_dummies(house_data['grade'],prefix='grade_')

# %%
house_data=pd.concat([house_data,df_grade],axis=1)

# %%
house_data.drop(['grade'],axis=1,inplace=True)

# %%
house_data.view.unique()
# Out:
# array([0, 3, 4, 2, 1], dtype=int64)

# %%
df_view=pd.get_dummies(house_data['view'],prefix='view_',drop_first=True)
house_data=pd.concat([house_data,df_view],axis=1)
house_data.drop(['view'],axis=1,inplace=True)

# %%
house_data['bathrooms_rounds']=house_data['bathrooms'].round(decimals=0)

# %%
house_data['bathrooms_rounds'].unique()
# Out:
# array([1., 2., 3., 4., 5., 0., 6., 7., 8.])

# %%
df_bath=pd.get_dummies(house_data['bathrooms_rounds'],prefix='bath_')
house_data=pd.concat([house_data,df_bath],axis=1)
house_data.drop(['bathrooms'],axis=1,inplace=True)

# %%
x=house_data[[ 'floors','waterfront', 'bedrooms__1', 'bedrooms__2', 'bedrooms__3',
       'bedrooms__4', 'bedrooms__5', 'bedrooms__6', 'bedrooms__7',
       'bedrooms__8', 'bedrooms__9', 'bedrooms__10', 'bedrooms__11',
       'Very_Small_Apt', 'Small_Apt', 'Medium_Apt', 'Large_apt', 'zip__98001',
       'zip__98002', 'zip__98003', 'zip__98004', 'zip__98005', 'zip__98006',
       'zip__98007', 'zip__98008', 'zip__98010', 'zip__98011', 'zip__98014',
       'zip__98019', 'zip__98022', 'zip__98023', 'zip__98024', 'zip__98027',
       'zip__98028', 'zip__98029', 'zip__98030', 'zip__98031', 'zip__98032',
       'zip__98033', 'zip__98034', 'zip__98038', 'zip__98039', 'zip__98040',
       'zip__98042', 'zip__98045', 'zip__98052', 'zip__98053', 'zip__98055',
       'zip__98056', 'zip__98058', 'zip__98059', 'zip__98065', 'zip__98070',
       'zip__98072', 'zip__98074', 'zip__98075', 'zip__98077', 'zip__98092',
       'zip__98102', 'zip__98103', 'zip__98105', 'zip__98106', 'zip__98107',
       'zip__98108', 'zip__98109', 'zip__98112', 'zip__98115', 'zip__98116',
       'zip__98117', 'zip__98118', 'zip__98119', 'zip__98122', 'zip__98125',
       'zip__98126', 'zip__98133', 'zip__98136', 'zip__98144', 'zip__98146',
       'zip__98148', 'zip__98155', 'zip__98166', 'zip__98168', 'zip__98177',
       'zip__98178', 'zip__98188', 'zip__98198', 'zip__98199', 'grade__1', 'grade__3','grade__4', 'grade__5', 'grade__6', 'grade__7', 'grade__8', 'grade__9',
       'grade__10', 'grade__11', 'grade__12', 'grade__13','view__1', 'view__2', 'view__3', 'view__4','bath__0.0', 'bath__1.0', 'bath__2.0', 'bath__3.0',
       'bath__4.0', 'bath__5.0', 'bath__6.0', 'bath__7.0', 'bath__8.0','house_age','sqft_lot','ppsq']]
y=house_data['price']

from sklearn.cross_validation import train_test_split
train_x, test_x, train_y, test_y = train_test_split(x,y,test_size=0.30, random_state=1234)


from sklearn.linear_model import LinearRegression
model1=LinearRegression()

model1.fit(train_x,train_y)
print("Train scrore: {}".format(model1.score(train_x,train_y)))
print("Test scrore: {}".format(model1.score(test_x,test_y)))
r_squared=model1.score(test_x,test_y)
r_squared_train=model1.score(train_x,train_y)
# Out:
# Train scrore: 0.881097310630998
# Test scrore: 0.8813476493783128

# %%
adjusted_r_squared = 1 - (1-r_squared)*(len(y)-1)/(len(y)-x.shape[1]-1)
adjusted_r_squared_train = 1 - (1-r_squared_train)*(len(y)-1)/(len(y)-x.shape[1]-1)

# %%
adjusted_r_squared
# Out:
# 0.880712879173554

# %%
adjusted_r_squared_train
# Out:
# 0.8804612011558661

# %%
pred_y = model1.predict(test_x)

plt.scatter(test_y, pred_y)

# %%
model1.coef_
# Out:
# array([ 1.26561708e+04,  2.85609302e+05, -1.26624474e+05, -1.17864014e+04,
#         4.37830992e+04,  5.22934528e+04,  7.13853767e+04,  6.69110885e+04,
#         7.16615175e+04,  5.70375875e+04, -1.86585117e+05,  4.85450317e+04,
#         6.87487980e+04, -1.56678210e+05, -4.77657321e+04,  3.83408668e+04,
#         1.66103075e+05, -3.87718913e+04, -1.86118069e+04, -4.22173056e+04,
#         2.49377496e+05,  2.54166151e+04,  1.01891345e+04, -1.51069145e+03,
#         2.71205456e+04, -5.22687423e+04, -2.55722969e+04, -3.60781621e+04,
#        -3.30988628e+04, -5.64604335e+04, -6.55439628e+04, -2.11250251e+04,
#        -1.43173982e+04, -2.44648972e+04,  4.12036307e+03, -4.99950121e+04,
#        -4.27322396e+04, -3.14535779e+04,  5.34588975e+04, -3.79366035e+03,
#        -4.45371992e+04,  5.16393895e+05,  1.61572639e+05, -4.56466757e+04,
#        -4.80861723e+04,  5.38778113e+03,  2.45044125e+04, -3.05194448e+04,
# ...
